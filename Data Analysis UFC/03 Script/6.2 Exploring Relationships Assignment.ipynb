# %% [markdown]
# # 6.2 Exploring Relationships

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
path = r'C:\\Users\\figue\\Data Analysis UFC'

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'UFC Data Set.csv'), index_col = False)

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Checking for errors and cleaning

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'Referee', 'date', 'location', 'Winner',
#        'title_bout', 'weight_class', 'B_avg_KD', 'B_avg_opp_KD',
#        'B_total_time_fought(seconds)', 'B_total_rounds_fought',
#        'B_total_title_bouts', 'B_current_win_streak', 'B_current_lose_streak',
#        'B_longest_win_streak', 'B_wins', 'B_losses', 'B_draw',
#        'B_win_by_Decision_Majority', 'B_win_by_Decision_Split',
#        'B_win_by_Decision_Unanimous', 'B_win_by_KO/TKO', 'B_win_by_Submission',
#        'B_win_by_TKO_Doctor_Stoppage', 'B_Stance', 'B_Height_cms',
#        'B_Weight_lbs', 'R_avg_KD', 'R_avg_opp_KD',
#        'R_total_time_fought(seconds)', 'R_total_rounds_fought',
#        'R_total_title_bouts', 'R_current_win_streak', 'R_current_lose_streak',
#        'R_longest_win_streak', 'R_wins', 'R_losses', 'R_draw',
#        'R_win_by_Decision_Majority', 'R_win_by_Decision_Split',
#        'R_win_by_Decision_Unanimous', 'R_win_by_KO/TKO', 'R_win_by_Submission',
# ...

# %%
# Dropping additional columns

df.drop(columns = ['B_avg_opp_KD', 'B_avg_KD', 'B_Height_cms', 'R_avg_opp_KD', 'R_avg_KD', 'R_Height_cms'])
# Out:
#             R_fighter      B_fighter         Referee       date  \
# 0        Adrian Yanez  Gustavo Lopez   Chris Tognoni  3/20/2021
# 1        Trevin Giles  Roman Dolidze       Herb Dean  3/20/2021
# 2       Marion Reneau  Macy Chiasson      Mark Smith  3/20/2021
# 3     Leonardo Santos   Grant Dawson   Chris Tognoni  3/20/2021
# 4          Song Kenan    Max Griffin  Keith Peterson  3/20/2021
# ...               ...            ...             ...        ...
# 4555    Patrick Smith   Scott Morris   John McCarthy  3/11/1994
# 4556     Royce Gracie  Remco Pardoel   John McCarthy  3/11/1994
# 4557    Remco Pardoel   Orlando Wiet   John McCarthy  3/11/1994
# 4558    Patrick Smith  Johnny Rhodes   John McCarthy  3/11/1994
# 4559     Royce Gracie  Jason DeLucia   John McCarthy  3/11/1994
#
#                     location Winner  title_bout       weight_class  \
# 0     Las Vegas, Nevada, USA    Red       False       Bantamweight
# ...

# %%
df = df.drop(columns = ['B_avg_opp_KD', 'B_avg_KD', 'B_Height_cms', 'R_avg_opp_KD', 'R_avg_KD', 'R_Height_cms'])

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'Referee', 'date', 'location', 'Winner',
#        'title_bout', 'weight_class', 'B_total_time_fought(seconds)',
#        'B_total_rounds_fought', 'B_total_title_bouts', 'B_current_win_streak',
#        'B_current_lose_streak', 'B_longest_win_streak', 'B_wins', 'B_losses',
#        'B_draw', 'B_win_by_Decision_Majority', 'B_win_by_Decision_Split',
#        'B_win_by_Decision_Unanimous', 'B_win_by_KO/TKO', 'B_win_by_Submission',
#        'B_win_by_TKO_Doctor_Stoppage', 'B_Stance', 'B_Weight_lbs',
#        'R_total_time_fought(seconds)', 'R_total_rounds_fought',
#        'R_total_title_bouts', 'R_current_win_streak', 'R_current_lose_streak',
#        'R_longest_win_streak', 'R_wins', 'R_losses', 'R_draw',
#        'R_win_by_Decision_Majority', 'R_win_by_Decision_Split',
#        'R_win_by_Decision_Unanimous', 'R_win_by_KO/TKO', 'R_win_by_Submission',
#        'R_win_by_TKO_Doctor_Stoppage', 'R_Stance', 'R_Weight_lbs', 'B_age',
#        'R_age'],
# ...

# %%
# renaming columns
df.rename(columns = {'title_bout' : 'Title Fight', 'B_total_time_fought(seconds)' : 'B Fight Duration(seconds)', 'B_total_rounds_fought' : 'B Rounds', 'B_total_title_bouts' : 'B Title Fights', 'R_total_time_fought(seconds)' : 'R Fight Duration(seconds)', 'R_total_rounds_fought' : 'R Rounds', 'R_total_title_bouts' : 'R Title Fights' }, inplace = True)

# %%
df = df.rename(columns = {'title_bout' : 'Title Fight', 'B_total_time_fought(seconds)' : 'B Fight Duration(seconds)', 'B_total_rounds_fought' : 'B Rounds', 'B_total_title_bouts' : 'B Title Fights', 'R_total_time_fought(seconds)' : 'R Fight Duration(seconds)', 'R_total_rounds_fought' : 'R Rounds', 'R_total_title_bouts' : 'R Title Fights' })

# %%
#Checking for changes

df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'Referee', 'date', 'location', 'Winner',
#        'Title Fight', 'weight_class', 'B Fight Duration(seconds)', 'B Rounds',
#        'B Title Fights', 'B_current_win_streak', 'B_current_lose_streak',
#        'B_longest_win_streak', 'B_wins', 'B_losses', 'B_draw',
#        'B_win_by_Decision_Majority', 'B_win_by_Decision_Split',
#        'B_win_by_Decision_Unanimous', 'B_win_by_KO/TKO', 'B_win_by_Submission',
#        'B_win_by_TKO_Doctor_Stoppage', 'B_Stance', 'B_Weight_lbs',
#        'R Fight Duration(seconds)', 'R Rounds', 'R Title Fights',
#        'R_current_win_streak', 'R_current_lose_streak', 'R_longest_win_streak',
#        'R_wins', 'R_losses', 'R_draw', 'R_win_by_Decision_Majority',
#        'R_win_by_Decision_Split', 'R_win_by_Decision_Unanimous',
#        'R_win_by_KO/TKO', 'R_win_by_Submission',
#        'R_win_by_TKO_Doctor_Stoppage', 'R_Stance', 'R_Weight_lbs', 'B_age',
#        'R_age'],
#       dtype='object')

# %%
df.dtypes
# Out:
# R_fighter                        object
# B_fighter                        object
# Referee                          object
# date                             object
# location                         object
# Winner                           object
# Title Fight                        bool
# weight_class                     object
# B Fight Duration(seconds)       float64
# B Rounds                          int64
# B Title Fights                    int64
# B_current_win_streak              int64
# B_current_lose_streak             int64
# B_longest_win_streak              int64
# B_wins                            int64
# B_losses                          int64
# B_draw                            int64
# B_win_by_Decision_Majority        int64
# B_win_by_Decision_Split           int64
# B_win_by_Decision_Unanimous       int64
# B_win_by_KO/TKO                   int64
# B_win_by_Submission               int64
# B_win_by_TKO_Doctor_Stoppage      int64
# ...

# %%
df.head()
# Out:
#          R_fighter      B_fighter         Referee       date  \
# 0     Adrian Yanez  Gustavo Lopez   Chris Tognoni  3/20/2021
# 1     Trevin Giles  Roman Dolidze       Herb Dean  3/20/2021
# 2    Marion Reneau  Macy Chiasson      Mark Smith  3/20/2021
# 3  Leonardo Santos   Grant Dawson   Chris Tognoni  3/20/2021
# 4       Song Kenan    Max Griffin  Keith Peterson  3/20/2021
#
#                  location Winner  Title Fight       weight_class  \
# 0  Las Vegas, Nevada, USA    Red        False       Bantamweight
# 1  Las Vegas, Nevada, USA    Red        False       Middleweight
# 2  Las Vegas, Nevada, USA   Blue        False  WomenBantamweight
# 3  Las Vegas, Nevada, USA   Blue        False        Lightweight
# 4  Las Vegas, Nevada, USA   Blue        False       Welterweight
#
#    B Fight Duration(seconds)  B Rounds  B Title Fights  B_current_win_streak  \
# 0                  531.50000         4               0                     0
# ...

# %% [markdown]
# ## Missing Values

# %%
df.isnull().sum()
# Out:
# R_fighter                         0
# B_fighter                         0
# Referee                           0
# date                              0
# location                          0
# Winner                            0
# Title Fight                       0
# weight_class                      0
# B Fight Duration(seconds)         0
# B Rounds                          0
# B Title Fights                    0
# B_current_win_streak              0
# B_current_lose_streak             0
# B_longest_win_streak              0
# B_wins                            0
# B_losses                          0
# B_draw                            0
# B_win_by_Decision_Majority        0
# B_win_by_Decision_Split           0
# B_win_by_Decision_Unanimous       0
# B_win_by_KO/TKO                   0
# B_win_by_Submission               0
# B_win_by_TKO_Doctor_Stoppage      0
# B_Stance                         11
# B_Weight_lbs                      0
# R Fight Duration(seconds)       269
# ...

# %%
# There is misssing data, but not enought to delete the rest of the data in that row

# %% [markdown]
# ## Duplicates

# %%
df_dups = df[df.duplicated ()]

# %%
df_dups.shape
# Out:
# (0, 44)

# %% [markdown]
# ## Mixed-Type Data

# %%
for col in df.columns.tolist():
    weird = (df[[col]]. map(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df[weird]) > 0:
        print (col)
# Out:
# B_Stance
# R_Stance

# %%
#this mixed data based on the fighter's prefered stance and will not cause any issues

# %% [markdown]
# # Correlation Heatmap

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'Referee', 'date', 'location', 'Winner',
#        'Title Fight', 'weight_class', 'B Fight Duration(seconds)', 'B Rounds',
#        'B Title Fights', 'B_current_win_streak', 'B_current_lose_streak',
#        'B_longest_win_streak', 'B_wins', 'B_losses', 'B_draw',
#        'B_win_by_Decision_Majority', 'B_win_by_Decision_Split',
#        'B_win_by_Decision_Unanimous', 'B_win_by_KO/TKO', 'B_win_by_Submission',
#        'B_win_by_TKO_Doctor_Stoppage', 'B_Stance', 'B_Weight_lbs',
#        'R Fight Duration(seconds)', 'R Rounds', 'R Title Fights',
#        'R_current_win_streak', 'R_current_lose_streak', 'R_longest_win_streak',
#        'R_wins', 'R_losses', 'R_draw', 'R_win_by_Decision_Majority',
#        'R_win_by_Decision_Split', 'R_win_by_Decision_Unanimous',
#        'R_win_by_KO/TKO', 'R_win_by_Submission',
#        'R_win_by_TKO_Doctor_Stoppage', 'R_Stance', 'R_Weight_lbs', 'B_age',
#        'R_age'],
#       dtype='object')

# %%
# Using a heat map to show red or blue side based off age
sub = df[['B_age', 'B_wins', 'B Rounds', 'B Title Fights', 'B_current_win_streak', 'B_current_lose_streak',
       'B_longest_win_streak', 'B Fight Duration(seconds)', 'B_losses',
       'B_win_by_Decision_Majority', 'B_win_by_Decision_Split',
       'B_win_by_Decision_Unanimous', 'B_win_by_KO/TKO', 'B_win_by_Submission',
       'B_win_by_TKO_Doctor_Stoppage', 'B_Weight_lbs']]

# %%
sub
# Out:
#       B_age  B_wins  B Rounds  B Title Fights  B_current_win_streak  \
# 0      31.0       1         4               0                     0
# 1      32.0       2         4               0                     2
# 2      29.0       4        11               1                     3
# 3      27.0       4        10               0                     4
# 4      35.0       4        28               0                     0
# ...     ...     ...       ...             ...                   ...
# 4555    NaN       1         1               0                     1
# 4556    NaN       2         2               0                     2
# 4557    NaN       1         1               0                     1
# 4558    NaN       2         2               0                     2
# 4559   24.0       1         1               0                     1
#
#       B_current_lose_streak  B_longest_win_streak  B Fight Duration(seconds)  \
# ...

# %%
# using matplotlib to create a subplot focusing on B fighters

f,ax = plt.subplots(figsize=(10,10))

corr = sns.heatmap(sub.corr(),annot = True, ax=ax)

fig = sns_heatmap.get_figure()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 7
#       3 f,ax = plt.subplots(figsize=(10,10))
#       5 corr = sns.heatmap(sub.corr(),annot = True, ax=ax)
# ----> 7 fig = sns_heatmap.get_figure()
#
# NameError: name 'sns_heatmap' is not defined

# %%
fig = sns.heatmap.get_figure()

# %%
#Removed columns with no strong correlations
df = df.drop(columns = ['B Fight Duration(seconds)', 'B_win_by_Decision_Majority', 'B_win_by_Decision_Split', 'B_win_by_TKO_Doctor_Stoppage'])

# %%
# This shows that there is minimal impact of age and wins

# %%
#current directory
cwd = os.getcwd()
cwd

# %%
sub_r = df[['R Fight Duration(seconds)', 'R Rounds', 'R Title Fights',
       'R_current_win_streak', 'R_current_lose_streak', 'R_longest_win_streak',
       'R_wins', 'R_losses', 'R_win_by_Decision_Majority',
       'R_win_by_Decision_Split', 'R_win_by_Decision_Unanimous',
       'R_win_by_KO/TKO', 'R_win_by_Submission',
       'R_win_by_TKO_Doctor_Stoppage', 'R_age', 'R_Weight_lbs']]

# %%
# using matplotlib to create a subplot focusing on R fighters
f,ax = plt.subplots(figsize=(10,10))

corr = sns.heatmap(sub_r.corr(),annot = True, ax=ax)

# %%
sub_r.columns

# %%
#Removed columns with no strong correlations
df = df.drop(columns = ['R Fight Duration(seconds)', 'R_win_by_Decision_Majority', 'R_win_by_Decision_Split', 'R_win_by_TKO_Doctor_Stoppage'])

# %% [markdown]
# # ScatterPlots

# %% [markdown]
# #### B Current win/lose streak correlation

# %%
sp=sns.lmplot(x = 'B_current_win_streak', y = 'B_current_lose_streak', data = df)

# %%
# Thought the heatmap shows that that the blue fighter's current win streak has a negative correlation with current lose streak,
# this scatterplot shows that the data is too loose to use.

# %%
# Save figure
sp.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'R_Current_Streak'))

# %% [markdown]
# #### R Current lose/win streak

# %%
sp_2=sns.lmplot(x = 'R_current_win_streak', y = 'R_current_lose_streak', data = df)

# %%
#Simliar to Blue Fighters, Red fighter's data does not show a clear trend despite the correlation in the heatmap.

# %%
sp_2.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'B_Current_Streak'))

# %% [markdown]
# #### Red Title fights and win streak

# %%
sp_3=sns.lmplot(x = 'R_current_win_streak', y = 'R Title Fights', data = df)

# %%
# There is not a strong trend on this dat either as having a 7 win streak has the highest amount of title fights, while having a 16 win streak is lower. However, it does show that win streaks do not have a strong impact on winning title fights.

# %%
sp_3.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'R_Title_Streak'))

# %% [markdown]
# #### Red fighter win by decision unanimous and number of rounds

# %%
sp_4=sns.lmplot(x = 'R_win_by_Decision_Unanimous', y = 'R Rounds', data = df)

# %%
# While the plot points are not in diagnal line, we can see a trend that the number of rounds influence the unanimous decision. This is also total rounds and could mean that the more rounds the fighter has means they are more experienced and are more likely to have a unanimous decision.

# %%
sp_4.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'R_Rounds_Unanimous'))

# %% [markdown]
# #### Blue fighter rounds and unanimous decison

# %%
sp_5=sns.lmplot(x = 'B_win_by_Decision_Unanimous', y = 'B Rounds', data = df)

# %%
# Similiar trend to red fighter which further confirms previous findings

# %%
sp_5.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'B_Rounds_Unanimous'))

# %% [markdown]
# #### Red fighter wins and rounds

# %%
sp_6=sns.lmplot(x = 'R_wins', y = 'R Rounds', data = df)

# %%
# Strongest correlation showing that wins and rounds show the more rounds (more fights) allow fighters to have higher chances of winning.

# %%
sp_6.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'R_Rounds_Wins'))

# %% [markdown]
# #### Blue fighter wins and rounds

# %%
sp_7=sns.lmplot(x = 'B_wins', y = 'B Rounds', data = df)

# %%
# Similiar trend to red fighters which confirms the interpretation of the impact of wins and rounds

# %%
sp_7.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'B_Rounds_Wins'))

# %% [markdown]
# # Pairplot

# %%
g = sns.pairplot(df)

# %%
#Had to open visualizion in different area. Discovered there is a trend in wins and losses based off rounds. This would show the importance of rounds and which side wins more often.

# %% [markdown]
# # Categorical Plots

# %% [markdown]
# #### Histplot Red fighter age

# %%
df['R_age'].value_counts()

# %%
sns.histplot(df['R_age'], bins = 20, kde = True)

# %% [markdown]
# #### Catplot Red fighter age

# %%
df.loc[df['R_age'] < 28, 'R_Age Range'] = 'Young Prospect'

# %%
df.loc[df['R_age'] >= 28, 'R_Age Range'] = 'Experienced'

# %%
df.loc[df['R_age'] >= 38, 'R_Age Range'] = 'Veteran'

# %%
df['R_Age Range'].value_counts(dropna = False)

# %%
#Categorical plot in seaborn with age and wins

sns.set(style="ticks")
cp = sns.catplot(x="R_wins", y="R_age", hue="R_Age Range", data=df)

# %% [markdown]
# #### Histplot blue fighter age

# %%
df['B_age'].value_counts()

# %%
sns.histplot(df['B_age'], bins = 20, kde = True)

# %% [markdown]
# #### Catplot blue fighter age

# %%
df.loc[df['B_age'] < 28, 'B_Age Range'] = 'Young Prospect'

# %%
df.loc[df['B_age'] >= 28, 'B_Age Range'] = 'Experienced'

# %%
df.loc[df['B_age'] >= 38, 'B_Age Range'] = 'Veteran'

# %%
df['B_Age Range'].value_counts(dropna = False)

# %%
sns.set(style="ticks")
cp_2 = sns.catplot(x="B_wins", y="B_age", hue="B_Age Range", data=df)

# %% [markdown]
# #### Catplot on red fighter age and number of rounds

# %%
sns.set(style="ticks")
cp_3 = sns.catplot(x="R Rounds", y="R_age", hue="R_Age Range", data=df, height=5, aspect=3)

# %%
# The older the fighter is the more rounds they last for

# %% [markdown]
# #### Catplot on blue fighter age and number of rounds

# %%
sns.set(style="ticks")
cp_4 = sns.catplot(x="B Rounds", y="B_age", hue="B_Age Range", data=df, height=5, aspect=3)

# %%
# This data is similiar to the previous data showing that age impacts the number of rounds a fighter can last

# %% [markdown]
# ## Questions and Answers

# %%
# A few questions such as which side wins more often and which side wins more title fights were not answered, better questions were shown through the data.
# I was able to identify trends between age and total wins, and age and number of rounds
# Additionally there were trends that were disproven such as win and loss streaks do not have a strong impact as it was depicted in the heat map.
# There was a strong trend of unanimous wins and number of rounds each fighter.
# There was a strong trend of number of rounds and wins

# %%
# Unanswered Questions
# There are questions based off of time and geographical location that will be answered in further scripts.

# %% [markdown]
# ## Hypothesis

# %%
# The more experienced the fighter is the more likely it will impact their career.

# %% [markdown]
# # Saving New Data Frame

# %%
df.to_csv(os.path.join(path, '02 Data','Prepared Data', 'UFC_Edited.csv'))
